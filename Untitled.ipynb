# %%
########################## http://edition.cnn.com/
import urllib2
import string
import pickle

URL_HTML = []
Web_URL = ['http://edition.cnn.com/', 'http://www.cnn.com']

for x in range(len(Web_URL)):
    source = urllib2.urlopen(Web_URL[x]).read()
    #print source # 추
print type(source)
# Out:
# <type 'str'>

# %%
########################## http://edition.cnn.com/
import urllib2
import string
import pickle

URL_HTML = []
Web_URL = ['http://www.times.com', 'https://www.amazon.com', 'https://github.com']

listsum = []
for x in range(len(Web_URL)):
    source = urllib2.urlopen(Web_URL[x]).read()
    listsum.append(source)
source = ''.join(listsum)

for i in range(0, source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")
#print source

for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")
#print source   # 순수 단어 출력

words = source.split() # 단어 나누기
l_punc = [] # 구두문자 리스트
l_word= [] # 단어들 리스트로(구두문자 없앤)
dic = {} # 사전 형식으로
s_punc = string.punctuation
ENG_stopword = [ 'a', 'and', 'are', 'as', 'at', 'be', 'but', 'by', 'for', 'if', 'in', 'into', 'is', 'it', 'no', 'not', 'of', 'on', 'or', 's', 'such', 't', 'that', 'the', 'their', 'then', 'there', 'these', 'they', 'this', 'to', 'was', 'will', 'with']

for x in s_punc:
    l_punc.append(x)
l_punc.append('‘')
l_punc.append('···')
l_punc.append('”')

for word in words:
    for y in l_punc:
        word = word.replace(y, '')
    if (word != ''):
        l_word.append(word)
        

l_word4 = [] # 영어 불용어 없앤 리스트        #1번

a = 0
for x in l_word:
    for y in ENG_stopword:
        a += 1
        if (x == y):
            a = 0
            break
    if(a == len(ENG_stopword)):
        l_word4.append(x)
        a = 0

#### 문제에서 불용어인 not을 지우라고 했지, Not을 지우라는 말이 없어서.. 
#### 따로 기능을 만들지 않았습니다.


for i in l_word4:
    cou = l_word4.count(i)
    dic[i] = cou

print dic
# Out:
# {'aspacingmedium': 1, 'hrefhttpwwwnytimescom20151203nyregionnewjerseymuslimsfeelsenseofbetrayalbychristiehtmlimg': 1, 'idasinshovelerns0N1GTRW911Y2RFE4Y32417377': 1, 'classinsidenytregion': 1, 'Until': 1, 'artscrafts': 1, 'eligible': 1, 'optsobfuscatedMarketId': 1, '': 1, 'MusicurlMP3MusicDownloadbieUTF8node163856011textKindle': 1, 'datasgproductquotasinquotquotB00ISH5K20quot': 1, '': 1, 'IndustrialitemstextAutomotiveitemstextAutomotive': 1, 'Blade': 4, 'JNew': 1, 'propertytwittertitle': 1, 'byspanspan': 1, 'itemclientWidth': 1, 'hrefgwftGrdesktopheroprime': 1, 'Sander': 2, 'srchttpecximagesamazoncomimagesI41RblphgT9LACSY220jpg': 1, 'datasgproductquotasinquotquotB007QUZ020quot': 1, 'solid': 7, 'classacolorprice15637spanpriceOnlyspan': 1, 'avisitednythpBriefingNewsletterSignup': 1, 'hrefd1y6jrbzotnyjgcloudfrontnet': 1, 'Sandy': 1, 'PdbBinder': 1, 'Screw': 4, 'BEN': 1, '2016ah6': 1, '0052': 1, '0051': 1, 'topspandiva': 1, 'atouch': 1, 'itemweightvaluereplaceunit': 1, 'classacolorprice2498spannodeIdnullimagesaltStanley': 1, 'hrefEditionUnlockedSmartphoneBlackWarrantydpB013SEXKI8img': 1, 'classfieldcontainer': 1, 'songstextDigital': 1, 'widget': 1, 'idapagescript': 1, 'issInitObject': 2, 'error': 2, 'ElectronicsurlComputersElectronicsServicesbieUTF8node10192836011textArts': 1, 'datastoryid100000004069980': 2, 'Primealilia': 1, 'hrefSamsungSmartWatchBlackWARRANTYdpB00JBJ3JBIimg': 1, 'datasgproductquotasinquotquotB00L3NY180quot': 1, 'k': 2, 'srchttpecximagesamazoncomimagesI61RTo5963MLPJStripePrimeOnly500pxTopLeft00ACSY220jpg': 1, 'reports': 3, 'classnavcartitemlink': 1, 'altLittle': 1, 'hrefhttpwwwnytimescomdigitalleftnavDigital': 1, 'sansserif': 3, 'fontfamilyArial': 1, 'hrefhttpwwwnytimescom20151203worldeuropebritainparliamentsyriaairstrikesvotehtmlBritish': 1, 'classacolorprice39999spanpriceOnlyspan': 2, 'replace': 1, 'purchasestextShop': 1, 'txt': 4, 'deploy\xe2\x80\x94all': 1, 'classkickerMortgages': 1, 'music': 4, 'Mediumpricespan': 1, 'valuesearchaliashandmadeHandmadeoption': 1, 'acolortertiary': 3, 'titleTile': 1, 'Charity': 2, 'namemsapplicationTileImage': 1, 'srchttpstatic01nytcomimages20151127world27BRUSSELS27BRUSSELSthumbStandardjpg': 1, 'datasgproductquotasinquotquotB00O4B74UAquot': 1, 'Rule': 5, '99': 3, 'buttongroup': 2, '90': 1, 'navarrow': 1, 'linkelementClass': 1, 'datasgproductquotasinquotquotB00I2TV3NOquot': 1, 'calengthdc': 1, 'navtransientflyouttrigger': 1, 'avisited': 2, 'toi0foro': 1, 'contenthttpsapigithubcomprivatebrowserstats': 1, 'selectedselected': 1, 'Positive': 1, 'hrefhttpwwwnytimescomsubscriptionsMultiproductlp5558htmlcampaignId37WXWSubscriptionsali': 1, 'Grocery': 1, 'hrefCanonEOST5ProfessionallightweightdpB00L3NY180img': 1, 'h1Why': 1, 'hrefNikonCOOLPIXDigitalOpticalBuiltIndpB00T85P56Cimg': 1, 'dialoghide': 2, 'absolute': 4, 'realEstateSearch': 1, 'Meets': 1, 'jsajaxerrordismiss': 1, 'hrefJawboneHeartActivitySleepTrackerdpB00N9E6DUKimg': 1, 'travel': 2, 'ifimagesToBeLoaded': 1, 'acceptcharsetUTF8': 2, '...': 1, 'tabindex20': 1, 'A': 25, 'classacolorprice17900spanpriceOnlyspan': 1, 'beauty': 3, 'classnavspritev1': 1, 'classshortcuts9A43D8FCF4CF44D99B34138D30468F8F': 1, 'wrong': 1, 'width519promoTypewidevertOffset11tabletAltTextnullhorizOffset18height492imagehttpgecximagesamazoncom ...

# %%
import urllib2
import string
import pickle
from operator import itemgetter

#for dic_key in dic:
#    print str(dic_key)+ " : "+str(dic[dic_key])


class WebWordsFrequency():
    def __init__(self, *i): # 2번
        self.l = list(i)
    
    def addUrl(self, i): # 3번
        self.l.append(i)
        
    def removeUrl(self, i): #4번
        if i in self.l:
            del self.l[int(self.l.index(i))]
        
    def listUrls(self): #5번
        for x in self.l:
            print x
            
    def getWordsFrequency(self): #6번
        if (len(self.l) == 0) :
            dic = {}
            print dic
        else:
            listsum = []
            for x in range(len(self.l)):
                source = urllib2.urlopen(self.l[x]).read()
                listsum.append(source)
            source = ''.join(listsum)

            for i in range(0, source.count('<!--')):
                if source.find("<!--") != -1:
                    source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")
            #print source

            for i in range(0,source.count("<")):
                if source.find("<") != -1:
                    source = source.replace(source[source.find("<"):source.find(">")+1:],"")
            #print source   # 순수 단어 출력

            words = source.split() # 단어 나누기
            l_punc = [] # 구두문자 리스트
            l_word= [] # 단어들 리스트로(구두문자 없앤)
            dic = {} # 사전 형식으로
            s_punc = string.punctuation
            ENG_stopword = [ 'a', 'and', 'are', 'as', 'at', 'be', 'but', 'by', 'for', 'if', 'in', 'into', 'is', 'it', 'no', 'not', 'of', 'on', 'or', 's', 'such', 't', 'that', 'the', 'their', 'then', 'there', 'these', 'they', 'this', 'to', 'was', 'will', 'with']

            for x in s_punc:
                l_punc.append(x)
            l_punc.append('‘')
            l_punc.append('···')
            l_punc.append('”')

            for word in words:
                for y in l_punc:
                    word = word.replace(y, '')
                if (word != ''):
                    l_word.append(word)


            l_word4 = [] # 영어 불용어 없앤 리스트        #1번

            a = 0
            for x in l_word:
                for y in ENG_stopword:
                    a += 1
                    if (x == y):
                        a = 0
                        break
                if(a == len(ENG_stopword)):
                    l_word4.append(x)
                    a = 0

            #### 문제에서 불용어인 not을 지우라고 했지, Not을 지우라는 말이 없어서.. 
            #### 따로 기능을 만들지 않았습니다.


            for i in l_word4:
                cou = l_word4.count(i)
                dic[i] = cou

            print dic
        
    def getMaxFreqencyWords(self): #7번
        if (len(self.l) == 0) :
            dic = {}
        else:
            listsum = []
            for x in range(len(self.l)):
                source = urllib2.urlopen(self.l[x]).read()
                listsum.append(source)
            source = ''.join(listsum)

            for i in range(0, source.count('<!--')):
                if source.find("<!--") != -1:
                    source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")
            #print source

            for i in range(0,source.count("<")):
                if source.find("<") != -1:
                    source = source.replace(source[source.find("<"):source.find(">")+1:],"")
            #print source   # 순수 단어 출력

            words = source.split() # 단어 나누기
            l_punc = [] # 구두문자 리스트
            l_word= [] # 단어들 리스트로(구두문자 없앤)
            dic = {} # 사전 형식으로
            s_punc = string.punctuation
            ENG_stopword = [ 'a', 'and', 'are', 'as', 'at', 'be', 'but', 'by', 'for', 'if', 'in', 'into', 'is', 'it', 'no', 'not', 'of', 'on', 'or', 's', 'such', 't', 'that', 'the', 'their', 'then', 'there', 'these', 'they', 'this', 'to', 'was', 'will', 'with']

            for x in s_punc:
                l_punc.append(x)
            l_punc.append('‘')
            l_punc.append('···')
            l_punc.append('”')

            for word in words:
                for y in l_punc:
                    word = word.replace(y, '')
                if (word != ''):
                    l_word.append(word)


            l_word4 = [] # 영어 불용어 없앤 리스트        #1번

            a = 0
            for x in l_word:
                for y in ENG_stopword:
                    a += 1
                    if (x == y):
                        a = 0
                        break
                if(a == len(ENG_stopword)):
                    l_word4.append(x)
                    a = 0

            #### 문제에서 불용어인 not을 지우라고 했지, Not을 지우라는 말이 없어서.. 
            #### 따로 기능을 만들지 않았습니다.


            for i in l_word4:
                cou = l_word4.count(i)
                dic[i] = cou
            y = dic
            l = []
            l = (sorted(y.iteritems(), key=itemgetter(1), reverse=True)) # 사전 값으로 정렬
            z = l[0][1]
            print l[0][0]
            num = len(l)

            for x in range(1,int(num)):
                if (z==l[x][1]):
                    print l[x][0]
                else :
                    break
            
        
#2번
w1 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com', 'https://www.amazon.com') 
w2 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com') 
w3 = WebWordsFrequency() 

#3번
w1.addUrl('https://github.com')
w3.addUrl('http://stackoverflow.com')

#4번
w1.removeUrl('http://www.cnn.com')
w2.removeUrl('http://stackoverflow.com')

#5번
w1.listUrls()

#6번
w1.getWordsFrequency() 

#7번
w1.getMaxFreqencyWords()

w4 = WebWordsFrequency() 
w4.getMaxFreqencyWords()
# Out:
# http://www.times.com
# https://www.amazon.com
# https://github.com
# {'aspacingmedium': 1, '': 1, 'hrefhttpwwwnytimescom20151203nyregionnewjerseymuslimsfeelsenseofbetrayalbychristiehtmlimg': 1, '5quot': 4, 'classinsidenytregion': 1, 'titleATAGLANCE': 2, 'LittmannreviewsauiStarClassMediumastarmedium45urlproductreviewsB00AZAMUR6encodingUTF8showViewpoints1numberOfRatings268hoverText45': 1, 'Until': 2, 'classacolorprice749spannodeIdnullimagesaltHouse': 1, 'artscrafts': 1, 'eligible': 1, 'optsobfuscatedMarketId': 1, 'MusicurlMP3MusicDownloadbieUTF8node163856011textKindle': 1, 'datasgproductquotasinquotquotB00ISH5K20quot': 1, 'IndustrialitemstextAutomotiveitemstextAutomotive': 1, '': 1, 'JNew': 1, 'propertytwittertitle': 1, 'byspanspan': 1, 'itemclientWidth': 1, 'hrefgwftGrdesktopheroprime': 1, 'Sander': 2, 'srchttpecximagesamazoncomimagesI41RblphgT9LACSY220jpg': 1, 'datasgproductquotasinquotquotB007QUZ020quot': 1, 'solid': 7, 'avisitednythpBriefingNewsletterSignup': 1, 'hrefd1y6jrbzotnyjgcloudfrontnet': 1, 'Sandy': 1, 'PdbBinder': 1, 'Screw': 4, 'BEN': 1, '2016ah6': 1, '0052': 1, '0051': 1, '': 1, 'topspandiva': 1, 'atouch': 1, 'itemweightvaluereplaceunit': 1, 'hrefoprahsfavoritethingspfrdmATVPDKIKX0DERpfrdsdesktopheroGpfrdr0E58QWC92J1TSE6B47X9pfrdt36701pfrdp2312981242pfrdidesktop': 1, 'imagemapns0E58QWC92J1TSE6B47X920216': 1, 'hrefhttpwwwnytimescomprivacyPrivacyali': 1, 'classfieldcontainer': 1, 'Presidential': 1, 'songstextDigital': 1, 'widget': 1, 'idapagescript': 1, 'issInitObject': 2, 'error': 2, 'datastoryid100000004069980': 2, 'Primealilia': 1, 'hrefSamsungSmartWatchBlackWARRANTYdpB00JBJ3JBIimg': 1, 'hrefdpB00LI0VA4QpfrdmATVPDKIKX0DERpfrdsdesktopheropivpfrdr0E58QWC92J1TSE6B47X9pfrdt36701pfrdp2249193782pfrdidesktopnn': 1, 'datasgproductquotasinquotquotB00L3NY180quot': 1, 'k': 2, 'srchttpecximagesamazoncomimagesI61RTo5963MLPJStripePrimeOnly500pxTopLeft00ACSY220jpg': 1, 'reports': 3, '': 1, 'classnavcartitemlink': 1, 'altLittle': 1, 'hrefhttpwwwnytimescomdigitalleftnavDigital': 1, 'SkyreviewsauiStarClassMediumastarmedium5urlproductreviewsB00ZWLJ3GYencodingUTF8showViewpoints1numberOfRatings4hoverText50': 1, 'sansserif': 3, 'fontfamilyArial': 1, 'hrefhttpwwwnytimescom20151203worldeuropebritainparliamentsyriaairstrikesvotehtmlBritish': 1, 'classacolorprice39999spanpriceOnlyspan': 1, 'replace': 1, 'purchasestextShop': 1, 'txt': 4, 'deploy\xe2\x80\x94all': 1, 'classkickerMortgages': 1, 'music': 4, 'Mediumpricespan': 1, 'valuesearchaliashandmadeHandmadeoption': 1, 'acolortertiary': 3, 'titleTile': 1, 'Charity': 2, 'namemsapplicationTileImage': 1, 'idnavimgmapnavsaandroid': 1, 'Chestpiece': 4, 'Rule': 1, '99': 3, 'buttongroup': 2, '90': 1, 'navarrow': 1, 'linkelementClass': 1, 'datasgproductquotasinquotquotB00I2TV3NOquot': 1, 'calengthdc': 1, 'navtransie ...
# div

# %%
import urllib2
import string
import pickle
from operator import itemgetter

#for dic_key in dic:
#    print str(dic_key)+ " : "+str(dic[dic_key])


class WebWordsFrequency():
    def __init__(self, *i): # 2번
        self.l = list(i)
    
    def addUrl(self, i): # 3번
        self.l.append(i)
        
    def removeUrl(self, i): #4번
        if i in self.l:
            del self.l[int(self.l.index(i))]
        
    def listUrls(self): #5번
        for x in self.l:
            print x
            
    def getWordsFrequency(self): #6번
        if (len(self.l) == 0) :
            dic = {}
            print dic
        else:
            listsum = []
            for x in range(len(self.l)):
                source = urllib2.urlopen(self.l[x]).read()
                listsum.append(source)
            source = ''.join(listsum)

            for i in range(0, source.count('<!--')):
                if source.find("<!--") != -1:
                    source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")
            #print source

            for i in range(0,source.count("<")):
                if source.find("<") != -1:
                    source = source.replace(source[source.find("<"):source.find(">")+1:],"")
            #print source   # 순수 단어 출력

            words = source.split() # 단어 나누기
            l_punc = [] # 구두문자 리스트
            l_word= [] # 단어들 리스트로(구두문자 없앤)
            dic = {} # 사전 형식으로
            s_punc = string.punctuation
            ENG_stopword = [ 'a', 'and', 'are', 'as', 'at', 'be', 'but', 'by', 'for', 'if', 'in', 'into', 'is', 'it', 'no', 'not', 'of', 'on', 'or', 's', 'such', 't', 'that', 'the', 'their', 'then', 'there', 'these', 'they', 'this', 'to', 'was', 'will', 'with']

            for x in s_punc:
                l_punc.append(x)
            l_punc.append('‘')
            l_punc.append('···')
            l_punc.append('”')

            for word in words:
                for y in l_punc:
                    word = word.replace(y, '')
                if (word != ''):
                    l_word.append(word)


            l_word4 = [] # 영어 불용어 없앤 리스트        #1번

            a = 0
            for x in l_word:
                for y in ENG_stopword:
                    a += 1
                    if (x == y):
                        a = 0
                        break
                if(a == len(ENG_stopword)):
                    l_word4.append(x)
                    a = 0

            #### 문제에서 불용어인 not을 지우라고 했지, Not을 지우라는 말이 없어서.. 
            #### 따로 기능을 만들지 않았습니다.


            for i in l_word4:
                cou = l_word4.count(i)
                dic[i] = cou

            print dic
        
    def getMaxFreqencyWords(self): #7번
        if (len(self.l) == 0) :
            dic = {}
        else:
            listsum = []
            for x in range(len(self.l)):
                source = urllib2.urlopen(self.l[x]).read()
                listsum.append(source)
            source = ''.join(listsum)

            for i in range(0, source.count('<!--')):
                if source.find("<!--") != -1:
                    source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")
            #print source

            for i in range(0,source.count("<")):
                if source.find("<") != -1:
                    source = source.replace(source[source.find("<"):source.find(">")+1:],"")
            #print source   # 순수 단어 출력

            words = source.split() # 단어 나누기
            l_punc = [] # 구두문자 리스트
            l_word= [] # 단어들 리스트로(구두문자 없앤)
            dic = {} # 사전 형식으로
            s_punc = string.punctuation
            ENG_stopword = [ 'a', 'and', 'are', 'as', 'at', 'be', 'but', 'by', 'for', 'if', 'in', 'into', 'is', 'it', 'no', 'not', 'of', 'on', 'or', 's', 'such', 't', 'that', 'the', 'their', 'then', 'there', 'these', 'they', 'this', 'to', 'was', 'will', 'with']

            for x in s_punc:
                l_punc.append(x)
            l_punc.append('‘')
            l_punc.append('···')
            l_punc.append('”')

            for word in words:
                for y in l_punc:
                    word = word.replace(y, '')
                if (word != ''):
                    l_word.append(word)


            l_word4 = [] # 영어 불용어 없앤 리스트        #1번

            a = 0
            for x in l_word:
                for y in ENG_stopword:
                    a += 1
                    if (x == y):
                        a = 0
                        break
                if(a == len(ENG_stopword)):
                    l_word4.append(x)
                    a = 0

            #### 문제에서 불용어인 not을 지우라고 했지, Not을 지우라는 말이 없어서.. 
            #### 따로 기능을 만들지 않았습니다.


            for i in l_word4:
                cou = l_word4.count(i)
                dic[i] = cou
            y = dic
            l = []
            l = (sorted(y.iteritems(), key=itemgetter(1), reverse=True)) # 사전 값으로 정렬
            z = l[0][1]
            totallist = []
            totallist.append(l[0][0])
            num = len(l)

            for x in range(1,int(num)):
                if (z==l[x][1]):
                    totallist.append(l[x][0])
                else :
                    break
            return totallist
        
#2번
w1 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com', 'https://www.amazon.com') 
w2 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com') 
w3 = WebWordsFrequency() 

#3번
w1.addUrl('https://github.com')
w3.addUrl('http://stackoverflow.com')

#4번
w1.removeUrl('http://www.cnn.com')
w2.removeUrl('http://stackoverflow.com')

#5번
w1.listUrls()

#6번
#w1.getWordsFrequency() 

#7번
#w1.getMaxFreqencyWords()

w4 = WebWordsFrequency() 
w4.getMaxFreqencyWords()
